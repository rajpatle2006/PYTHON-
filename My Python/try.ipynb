# %%
print("hihqwiud ")
# Out:
# hihqwiud

# %%
st={1,2,3,1,2,3,'hello',3.5,(4,5,6,7)}
st.add(20)
# st.add(20,3,4)
st.update((50,73,4))
print(st)
# Out:
# {1, 2, 3.5, 3, 4, 73, 20, 'hello', 50, (4, 5, 6, 7)}

# %%
A = {1, 2}
B = {2, 3}

print(A | B)
print(A & B)
print(A - B)

# %%
s = {1,2,3,4,5}
s1={3,4,6,7,8}
print("union",s|s1)
print("intersecytion", s&s1)
print("differance" , s-s1)
print("symetric differance",s^s1)
# Out:
# union {1, 2, 3, 4, 5, 6, 7, 8}
# intersecytion {3, 4}
# differance {1, 2, 5}
# symetric differance {1, 2, 5, 6, 7, 8}
